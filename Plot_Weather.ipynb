# %%
import matplotlib.pyplot as plt
#import seaborn as sns
import pandas as pd
import plotly.express as px

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9dc88a6b-7853-40b6-9dc5-b0ce81293d8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9dc88a6b-7853-40b6-9dc5-b0ce81293d8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weathersensor.xlsx to weathersensor.xlsx

# %%
import io

for key, value in uploaded.items():
  filename = key

# %%
df1 = pd.read_excel(io.BytesIO(uploaded[filename]))
df1.dtypes
df1
# Out:
#             Date      Time  ... Wind Direction  Lightning Strike
# 0     2022/01/31  15:45:00  ...             71                 0
# 1     2022/01/31  16:00:00  ...             55                 0
# 2     2022/01/31  16:15:00  ...             54                 0
# 3     2022/01/31  16:30:00  ...             45                 0
# 4     2022/01/31  16:45:00  ...             63                 0
# ...          ...       ...  ...            ...               ...
# 1195  2022/02/14  11:30:00  ...            175                 0
# 1196  2022/02/14  11:45:00  ...             27                 0
# 1197  2022/02/14  12:00:00  ...            118                 0
# 1198  2022/02/14  12:15:00  ...             83                 0
# 1199  2022/02/14  12:30:00  ...             89                 0
#
# [1200 rows x 12 columns]

# %%
from datetime import datetime
dt1 = [datetime. strptime(i, '%Y/%m/%d %H:%M:%S') for i in df1['DateTime']]
dt1 = pd.DataFrame(dt1)
dt1
df1 = pd.concat([dt1, df1, ], axis = 1)
df1 = df1.rename(columns = {0 : "Date&Time"})
df1.dtypes
df1
# Out:
#                Date&Time        Date  ... Wind Direction Lightning Strike
# 0    2022-01-31 15:45:00  2022/01/31  ...             71                0
# 1    2022-01-31 16:00:00  2022/01/31  ...             55                0
# 2    2022-01-31 16:15:00  2022/01/31  ...             54                0
# 3    2022-01-31 16:30:00  2022/01/31  ...             45                0
# 4    2022-01-31 16:45:00  2022/01/31  ...             63                0
# ...                  ...         ...  ...            ...              ...
# 1195 2022-02-14 11:30:00  2022/02/14  ...            175                0
# 1196 2022-02-14 11:45:00  2022/02/14  ...             27                0
# 1197 2022-02-14 12:00:00  2022/02/14  ...            118                0
# 1198 2022-02-14 12:15:00  2022/02/14  ...             83                0
# 1199 2022-02-14 12:30:00  2022/02/14  ...             89                0
#
# [1200 rows x 13 columns]

# %%
fig = px.line(df1, y='ET Rate', x='Date&Time',
              # color='Lightning Strike'
              )
fig.update_layout(autosize=False,width=1100,height=550)
#fig.write_image("fig1.pdf")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-96d1af0f-5293-488f-a1da-8a13e5665aa8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96d1af0f-5293-488f-a1da-8a13e5665aa8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sensor.xlsx to sensor.xlsx

# %%
import io

for key, value in uploaded.items():
  filename = key

# %%
df2 = pd.read_excel(io.BytesIO(uploaded[filename]))
df2.dtypes
df2
# Out:
#            Sensor                  Date  ... Dielectric Moisture
# 0      G1A0000486  Jan 15, 2022 4:27 PM  ...          9       19
# 1      G1A0000486  Jan 15, 2022 5:20 PM  ...          9       19
# 2      G1A0000486  Jan 15, 2022 6:24 PM  ...          9       19
# 3      G1A0000486  Jan 15, 2022 7:27 PM  ...          9       19
# 4      G1A0000486  Jan 15, 2022 8:20 PM  ...          9       19
# ...           ...                   ...  ...        ...      ...
# 11111  G1A0000443  Feb 6, 2022 10:28 PM  ...         27       44
# 11112  G1A0000443  Feb 6, 2022 11:21 PM  ...         26       43
# 11113  G1A0000443  Feb 7, 2022 12:24 AM  ...         25       42
# 11114  G1A0000443   Feb 7, 2022 1:28 AM  ...         24       42
# 11115  G1A0000443   Feb 7, 2022 1:49 AM  ...         24       41
#
# [11116 rows x 8 columns]

# %%
# a = "Jan 5, 2022 11:27 PM"
# datetime. strptime(a, '%b %d, %Y %I:%M %p')
from datetime import datetime
dt2 = [datetime. strptime(i, '%b %d, %Y %I:%M %p') for i in df2['Date']]
dt2 = pd.DataFrame(dt2)

df2 = pd.concat([dt2, df2, ], axis = 1)
df2 = df2.rename(columns = {0 : "DateTime"})
df2
# Out:
#                  DateTime      Sensor  ... Dielectric Moisture
# 0     2022-01-15 16:27:00  G1A0000486  ...          9       19
# 1     2022-01-15 17:20:00  G1A0000486  ...          9       19
# 2     2022-01-15 18:24:00  G1A0000486  ...          9       19
# 3     2022-01-15 19:27:00  G1A0000486  ...          9       19
# 4     2022-01-15 20:20:00  G1A0000486  ...          9       19
# ...                   ...         ...  ...        ...      ...
# 11111 2022-02-06 22:28:00  G1A0000443  ...         27       44
# 11112 2022-02-06 23:21:00  G1A0000443  ...         26       43
# 11113 2022-02-07 00:24:00  G1A0000443  ...         25       42
# 11114 2022-02-07 01:28:00  G1A0000443  ...         24       42
# 11115 2022-02-07 01:49:00  G1A0000443  ...         24       41
#
# [11116 rows x 9 columns]

# %%
df2.sort_values(by=['DateTime'])
# Out:
#                 DateTime      Sensor  ... Dielectric Moisture
# 9746 2022-01-15 15:57:00  G1A0000362  ...          9       18
# 8491 2022-01-15 16:07:00  G1A0000474  ...          9       20
# 2784 2022-01-15 16:14:00  G1A0000460  ...          6       12
# 4224 2022-01-15 16:15:00  G1A0000444  ...          7       15
# 6379 2022-01-15 16:19:00  G1A0000382  ...         16       32
# ...                  ...         ...  ...        ...      ...
# 7818 2022-02-14 15:16:00  G1A0000356  ...          8       16
# 5657 2022-02-14 15:27:00  G1A0000484  ...         10       21
# 2063 2022-02-14 15:29:00  G1A0000498  ...          9       18
# 632  2022-02-14 15:29:00  G1A0000486  ...         10       21
# 5658 2022-02-14 15:37:00  G1A0000484  ...         10       21
#
# [11116 rows x 9 columns]

# %%
fig = px.line(df2, y='Ground Temp', x='DateTime',
              color='Sensor'
              )

fig.update_layout(autosize=False,width=2000,height=800)
#fig.write_image("fig1.pdf")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dt1 = df1[['Date&Time','Air Temp']]
dt1['Sensor'] = 'Air Temperature'
dt1 = dt1.rename(columns = {"Date&Time": 'DateTime'})
dt1 = dt1.rename(columns = {"Air Temp": 'Temp'})
dt1
dt2 = df2[['DateTime', 'Ground Temp', 'Sensor']]
dt2 = dt2.rename(columns = {"Ground Temp": 'Temp'})
dt2
finaldt = pd.concat([dt1, dt2, ])
finaldt
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  DateTime  Temp           Sensor
# 0     2022-01-31 15:45:00    16  Air Temperature
# 1     2022-01-31 16:00:00    16  Air Temperature
# 2     2022-01-31 16:15:00    16  Air Temperature
# 3     2022-01-31 16:30:00    15  Air Temperature
# 4     2022-01-31 16:45:00    15  Air Temperature
# ...                   ...   ...              ...
# 11111 2022-02-06 22:28:00    19       G1A0000443
# 11112 2022-02-06 23:21:00    19       G1A0000443
# 11113 2022-02-07 00:24:00    19       G1A0000443
# 11114 2022-02-07 01:28:00    19       G1A0000443
# 11115 2022-02-07 01:49:00    19       G1A0000443
#
# ...

# %%
fig = px.line(finaldt.query("DateTime>2022.02"), y='Temp', x='DateTime',
              color='Sensor'
              )

fig.update_layout(autosize=False,width=1100,height=550)
#fig.write_image("fig1.pdf")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ef0b71cf-cc65-4874-8a17-9e0b3af99a51" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef0b71cf-cc65-4874-8a17-9e0b3af99a51">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Turf_All_Events_test.xlsx to Turf_All_Events_test.xlsx

# %%
import io

for key, value in uploaded.items():
  filename = key

# %%
df3 = pd.read_excel(io.BytesIO(uploaded[filename]))
df3.dtypes
df3
# Out:
#           Sensor       EventDateTime  ...                Type   Health
# 0     G1A0000382 2021-08-09 10:49:00  ...  Creeping Bentgrass  Healthy
# 1     G1A0000382 2021-08-09 09:09:00  ...  Creeping Bentgrass  Healthy
# 2     G1A0000382 2021-08-09 08:39:00  ...  Creeping Bentgrass  Healthy
# 3     G1A0000382 2021-08-09 07:19:00  ...  Creeping Bentgrass  Healthy
# 4     G1A0000382 2021-08-09 06:59:00  ...  Creeping Bentgrass  Healthy
# ...          ...                 ...  ...                 ...      ...
# 2174  G1A0000485 2021-08-07 23:27:00  ...          Bent Grass  Healthy
# 2175  G1A0000485 2021-08-07 19:38:00  ...          Bent Grass  Healthy
# 2176  G1A0000485 2021-08-07 16:48:00  ...          Bent Grass  Healthy
# 2177  G1A0000485 2021-08-07 14:39:00  ...          Bent Grass  Healthy
# 2178  G1A0000485 2021-08-07 12:39:00  ...          Bent Grass  Healthy
#
# [2179 rows x 10 columns]

# %%
anomaly = ['G1A0000382']
df3['Health'] = df3.Sensor.isin(anomaly)
# df3.Sensor.c
df3
# Out:
#           Sensor       EventDateTime  ...                Type  Health
# 0     G1A0000382 2021-08-09 10:49:00  ...  Creeping Bentgrass    True
# 1     G1A0000382 2021-08-09 09:09:00  ...  Creeping Bentgrass    True
# 2     G1A0000382 2021-08-09 08:39:00  ...  Creeping Bentgrass    True
# 3     G1A0000382 2021-08-09 07:19:00  ...  Creeping Bentgrass    True
# 4     G1A0000382 2021-08-09 06:59:00  ...  Creeping Bentgrass    True
# ...          ...                 ...  ...                 ...     ...
# 2174  G1A0000485 2021-08-07 23:27:00  ...          Bent Grass   False
# 2175  G1A0000485 2021-08-07 19:38:00  ...          Bent Grass   False
# 2176  G1A0000485 2021-08-07 16:48:00  ...          Bent Grass   False
# 2177  G1A0000485 2021-08-07 14:39:00  ...          Bent Grass   False
# 2178  G1A0000485 2021-08-07 12:39:00  ...          Bent Grass   False
#
# [2179 rows x 10 columns]

# %%
# fig = px.line(df3.query("EventDateTime>2021.02"), y='Moisture', x='EventDateTime',
#               color='Health',
#               line_group='Sensor',
#               hover_name="Sensor",
#               # line_shape="spline", 
#               render_mode="svg"
#               )
# fig = px.scatter_3d(df3, x="EventDateTime", y="Moisture", z="Health", color="Health", size="Salinity", hover_name="Sensor",
#                   # symbol="Sensor", 
#                   color_discrete_map = { "True": "green", "False":"red", "True": "blue"})

fig = px.scatter_mapbox(df3, lat="Latitude", lon="Longtitude", color="Health", 
                        size='Moisture', hover_name="Sensor",
                  color_continuous_scale=px.colors.cyclical.IceFire, 
                  size_max=7, 
                  zoom=14,
                  mapbox_style="open-street-map"
                  )

fig.update_layout(autosize=False, 
                  width=1100,height=550
                  )
#fig.write_image("fig1.pdf")
fig.show()
fig.write_html("sensorhealth.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import folium 

m = folium.Map([8.5077,76.9487], 
               zoom_start=17)

html="""
    <h1> This Is Big Pop Up </h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """
html = """
<h1> Have A Good Day </h1><br>
Rijin : Hi Bro. I have been working here
        for a few years...
"""
iframe = folium.IFrame(html=html, 
                       width=150, height=185)
popup = folium.Popup(iframe, max_width=200)

folium.Marker([8.5077,76.9487], popup=popup).add_to(m)

m.save("rijin.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
